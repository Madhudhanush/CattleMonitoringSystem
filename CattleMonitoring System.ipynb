# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 8.1 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KqDSBOuMOHVg9JwOOqFZ")
project = rf.workspace("madhudhanush").project("cattle-ypgb2")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.28, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Cattle-2 in yolov8:: 100%|██████████| 1316/1316 [00:00<00:00, 6006.85it/s]

# %%
from ultralytics import YOLO
model=YOLO('yolov8m.pt')
results=model.train(data='/content/Cattle-2/data.yaml',save=True,epochs=100)
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 335MB/s]
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model=YOLO("/content/runs/detect/train/weights/best.pt")

# %%
model=YOLO("/content/runs/detect/train/weights/best.pt")
results=model.predict("/content/Cattle-2/test/images",save=True)
# Out:
# image 1/48 /content/Cattle-2/test/images/Eating-107-_jpg.rf.151ef46d1f8aa7a46cb3120e8add0682.jpg: 640x640 1 Eating, 37.1ms
# image 2/48 /content/Cattle-2/test/images/Eating-11-_jpg.rf.47b283f1da5cab4c847886483a8895d8.jpg: 640x640 1 Siting, 37.1ms
# image 3/48 /content/Cattle-2/test/images/Eating-13-_jpg.rf.b8a06ca7d54be16c74e375e0e8d244ad.jpg: 640x640 1 Eating, 1 Siting, 37.1ms
# image 4/48 /content/Cattle-2/test/images/Eating-27-_jpg.rf.920e871357ca7207b7c8d017f47bcaf5.jpg: 640x640 1 Eating, 1 Siting, 34.8ms
# image 5/48 /content/Cattle-2/test/images/Eating-28-_jpg.rf.3edc1e9fee3b996a507fe63dbba210d9.jpg: 640x640 1 Eating, 34.8ms
# image 6/48 /content/Cattle-2/test/images/Eating-4-_jpg.rf.8cbfed75026dc181d0affad413771c5e.jpg: 640x640 2 Eatings, 34.7ms
# image 7/48 /content/Cattle-2/test/images/Eating-41-_jpg.rf.c9e6a824cfbf46c2be552c95522a649e.jpg: 640x640 1 Eating, 29.0ms
# ...

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/F1_curve.png")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/PR_curve.png")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/P_curve.png")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/confusion_matrix.png")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/confusion_matrix_normalized.png")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/labels.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/labels_correlogram.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/train_batch0.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/train_batch2222.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
import matplotlib.pyplot as plt
import cv2 as cv
img = cv.imread("/content/runs/detect/train/val_batch0_labels.jpg")
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
from ultralytics import YOLO


model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model("/content/Cattle-2/train/images/Falling-24-_jpg.rf.32a7e880a0cb2db5822cb319be17309e.jpg",save=True)
# Out:
# image 1/1 /content/Cattle-2/train/images/Falling-24-_jpg.rf.32a7e880a0cb2db5822cb319be17309e.jpg: 640x640 1 Falling, 37.0ms
# Speed: 1.5ms preprocess, 37.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
from ultralytics import YOLO


model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model("/content/Cattle-2/train/images/Falling-10-_jpg.rf.23ec3af69a415501a93e0e368f1d5126.jpg",save=True)
# Out:
# image 1/1 /content/Cattle-2/train/images/Falling-10-_jpg.rf.23ec3af69a415501a93e0e368f1d5126.jpg: 640x640 1 Eating, 1 Falling, 37.1ms
# Speed: 3.4ms preprocess, 37.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %%
from ultralytics import YOLO


model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model("/content/Cattle-2/train/images/Falling-12-_jpg.rf.5799d555b45dc2fd9e4a7f0d75ee1661.jpg",save=True)
# Out:
# image 1/1 /content/Cattle-2/train/images/Falling-12-_jpg.rf.5799d555b45dc2fd9e4a7f0d75ee1661.jpg: 640x640 1 Falling, 37.1ms
# Speed: 1.5ms preprocess, 37.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict4

# %%
from ultralytics import YOLO


model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model("/content/Cattle-2/train/images/Falling-17-_jpg.rf.611ce790c04cd5a152ce16d27eb2216a.jpg",save=True)
# Out:
# image 1/1 /content/Cattle-2/train/images/Falling-17-_jpg.rf.611ce790c04cd5a152ce16d27eb2216a.jpg: 640x640 2 Fallings, 1 Siting, 37.0ms
# Speed: 2.7ms preprocess, 37.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5

# %%
from ultralytics import YOLO


model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model("/content/Cattle-2/train/images/Falling-21-_jpg.rf.79c8552353cd309c987575b02ce97c4e.jpg",save=True)
# Out:
# image 1/1 /content/Cattle-2/train/images/Falling-21-_jpg.rf.79c8552353cd309c987575b02ce97c4e.jpg: 640x640 1 Falling, 39.3ms
# Speed: 1.8ms preprocess, 39.3ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict6

# %%
from ultralytics import YOLO


model = YOLO("/content/runs/detect/train/weights/best.pt")

results = model("/content/Cattle-2/train/images/Falling-29-_jpg.rf.05299be8c39971e2069c6847f5b37dcb.jpg",save=True)
# Out:
# image 1/1 /content/Cattle-2/train/images/Falling-29-_jpg.rf.05299be8c39971e2069c6847f5b37dcb.jpg: 640x640 1 Falling, 37.0ms
# Speed: 1.6ms preprocess, 37.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict7
